# %%
import numpy as np
import pandas as pd

Fahrenheit2Celsius = np.arange(0,101,10)

Fahrenheit =(Fahrenheit2Celsius*1.8)+32

TempChart = {"Celsius":Fahrenheit2Celsius, "Fahrenheit":Fahrenheit}
df = pd.DataFrame(TempChart)
df
# Out:
#     Celsius  Fahrenheit
# 0         0        32.0
# 1        10        50.0
# 2        20        68.0
# 3        30        86.0
# 4        40       104.0
# 5        50       122.0
# 6        60       140.0
# 7        70       158.0
# 8        80       176.0
# 9        90       194.0
# 10      100       212.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3

filename = 'Volve production data.xlsx'
xl = pd.ExcelFile('Volve production data.xlsx')
dailyDF = xl.parse('Daily Production Data')

conn = sqlite3.connect("VolveProduction.db")
cur = conn.cursor()
